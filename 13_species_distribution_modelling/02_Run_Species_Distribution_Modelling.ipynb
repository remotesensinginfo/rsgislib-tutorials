# %% [markdown]
# # Run SDM for Snowdon Beetle (*Chrysolina cerealis*)
#
# Now you have prepared the data layers, the next stage is to run the Species Distribution Modelling (SDM).

# %% [markdown]
# ## Import Modules

# %%
import glob
import os

import rsgislib
import rsgislib.imageutils
import rsgislib.tools.filetools
import rsgislib.tools.utils
import rsgislib.vectorutils
import species_distribution

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import rsgislib.tools.mapping

# %% [markdown]
# ## Create Output Data Directories

# %%
out_dir = "sdm_LogReg_outs"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

tmp_dir = "tmp_dir"
if not os.path.exists(tmp_dir):
    os.mkdir(tmp_dir)

# %% [markdown]
# ## Set all GTIFF Image Outputs to be Compressed

# %%
rsgislib.imageutils.set_env_vars_lzw_gtiff_outs()

# %% [markdown]
# ## Define Input Data Files

# %%
# Sighting (Presence) Data
presence_sightings_vec_file = "Chrysolina_cerealis_osgb.geojson"
presence_sightings_vec_lyr = "Chrysolina_cerealis_osgb"

# ROI Mask Image
study_site_msk_img = "Study_Area.tif"

# Environmental Images:
elevation_img = "../data/sdm/environmental_data/elevation.tif"
winter_temp_img = "../data/sdm/environmental_data/Mean_Winter_Temp.tif"
dist_phase1_imgs = glob.glob("phase1_dist_imgs/*.tif")

# %% [markdown]
# ## 1. Create Pseudo Absences

# %%
pseudo_absences_vec_lyr = "pseudo_absences"
pseudo_absences_vec_file = os.path.join(out_dir, f"{pseudo_absences_vec_lyr}.geojson")

species_distribution.gen_pseudo_absences_smpls(
    in_msk_img=study_site_msk_img,
    img_msk_val=1,
    out_vec_file=pseudo_absences_vec_file,
    out_vec_lyr=pseudo_absences_vec_lyr,
    n_smpls=1000,
    xtra_n_smpls=5000,
    presence_smpls_vec_file=presence_sightings_vec_file,
    presence_smpls_vec_lyr=presence_sightings_vec_lyr,
    presence_smpls_dist_thres=250,
    out_format="GeoJSON",
    rnd_seed=None,
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6000/6000 [00:00<00:00, 66570.44it/s]
# 1
# 1

# %% [markdown]
# ## 2. Create the dictionary of Environmental Variables

# %%
env_vars = dict()
env_vars["elevation"] = species_distribution.EnvVarInfo(
    name="elevation",
    file=elevation_img,
    band=1,
    data_type=rsgislib.VAR_TYPE_CONTINUOUS,
    min_vld_val=0,
    max_vld_val=2500,
)

env_vars["winter temperature"] = species_distribution.EnvVarInfo(
    name="winter temperature",
    file=winter_temp_img,
    band=1,
    data_type=rsgislib.VAR_TYPE_CONTINUOUS,
    min_vld_val=0,
    max_vld_val=10,
)

# Loop through the distance image and create the EnvVarInfo
# objects for each distance image.
for dist_img in dist_phase1_imgs:
    print(dist_img)
    dist_basename = rsgislib.tools.filetools.get_file_basename(dist_img)
    dist_name = dist_basename.replace("_", " ").lower()
    print(f"\t{dist_name}")

    env_vars[dist_name] = species_distribution.EnvVarInfo(
        name=dist_name,
        file=dist_img,
        band=1,
        data_type=rsgislib.VAR_TYPE_CONTINUOUS,
        min_vld_val=0,
        max_vld_val=20000,
    )
# Out:
# phase1_dist_imgs/Quarry_dist.tif
# 	quarry dist
# phase1_dist_imgs/Lichenbryophyte_heath_dist.tif
# 	lichenbryophyte heath dist
# phase1_dist_imgs/Fen_dist.tif
# 	fen dist
# phase1_dist_imgs/mosaic_dist.tif
# 	mosaic dist
# phase1_dist_imgs/Blanket_bog_dist.tif
# 	blanket bog dist
# phase1_dist_imgs/Wet_heath_dist.tif
# 	wet heath dist
# phase1_dist_imgs/Planted_coniferous_woodland_dist.tif
# 	planted coniferous woodland dist
# phase1_dist_imgs/Natural_rock_exposure_dist.tif
# 	natural rock exposure dist
# phase1_dist_imgs/Planted_broadleaved_woodland_dist.tif
# 	planted broadleaved woodland dist
# phase1_dist_imgs/Acidneutral_scree_dist.tif
# 	acidneutral scree dist
# phase1_dist_imgs/Improved_grassland_dist.tif
# 	improved grassland dist
# phase1_dist_imgs/Flush_and_spring_dist.tif
# 	flush and spring dist
# phase1_dist_imgs/Ephemeralshort_perennial_dist.tif
# 	ephemeralshort perennial dist
# phase1_dist_imgs/Unimproved_calcareous_grassland_dist.tif
# 	unimproved calcareous grassland dist
# phase1_dist_imgs/Spoil_dist.tif
# 	spoil dist
# phase1_dist_imgs/Upland_species_rich_ledges_dist.tif
# 	upland species rich ledges dist
# phase1_dist_imgs/Basin_mire_dist.tif
# 	basin mire dist
# phase1_dist_imgs/Bare_ground_dist.tif
# 	bare ground dist
# phase1_dist_imgs/Semi_natural_broadleaved_woodland_dist.tif
# 	semi natural broadleaved woodland dist
# phase1_dist_imgs/Marshy_grassland_Juncus_dominated_dist.tif
# 	marshy grassland juncus dominated dist
# phase1_dist_imgs/Swamp_dist.tif
# 	swamp dist
# phase1_dist_imgs/Basic_dry_heathcalcareous_grassland_mosaic_dist.tif
# 	basic dry heathcalcareous grassland mosaic dist
# phase1_dist_imgs/Semi_improved_neutral_grassland_dist.tif
# 	semi improved neutral grassland dist
# phase1_dist_imgs/Semi_improved_acid_grassland_dist.tif
# 	semi improved acid grassland dist
# phase1_dist_imgs/Track_not_comprehensively_digitised_dist.tif
# 	track not comprehensively digitised dist
# phase1_dist_imgs/Scree_dist.tif
# 	scree dist
# phase1_dist_imgs/Wet_heathacid_grassland_mosaic_dist.tif
# 	wet heathacid grassland mosaic dist
# phase1_dist_imgs/Dry_modified_bog_dist.tif
# 	dry modified bog dist
# phase1_dist_imgs/Non_ruderal_herb_and_fern_dist.tif
# 	non ruderal herb and fern dist
# phase1_dist_imgs/Marshy_grassland_Molinia_dominated_dist.tif
# 	marshy grassland molinia dominated dist
# phase1_dist_imgs/Marshy_grassland_dist.tif
# 	marshy grassland dist
# phase1_dist_imgs/Other_rock_exposure_dist.tif
# 	other rock exposure dist
# phase1_dist_imgs/Dry_acid_heath_dist.tif
# 	dry acid heath dist
# phase1_dist_imgs/Buildings_dist.tif
# 	buildings dist
# phase1_dist_imgs/Dense_scrub_dist.tif
# 	dense scrub dist
# phase1_dist_imgs/Standing_water_dist.tif
# 	standing water dist
# phase1_dist_imgs/Acidneutral_rock_dist.tif
# 	acidneutral rock dist
# phase1_dist_imgs/Unimproved_acid_grassland_dist.tif
# 	unimproved acid grassland dist
# phase1_dist_imgs/Running_water_dist.tif
# 	running water dist
# phase1_dist_imgs/Gardens_dist.tif
# 	gardens dist
# phase1_dist_imgs/Acidneutral_flush_dist.tif
# 	acidneutral flush dist
# phase1_dist_imgs/Brophyte_dominated_spring_dist.tif
# 	brophyte dominated spring dist
# phase1_dist_imgs/Bare_peat_dist.tif
# 	bare peat dist
# phase1_dist_imgs/Amenity_grassland_dist.tif
# 	amenity grassland dist
# phase1_dist_imgs/Bracken_dist.tif
# 	bracken dist
# phase1_dist_imgs/Wet_modified_bog_dist.tif
# 	wet modified bog dist

# %%
analysis_vars = list()
for var in env_vars:
    analysis_vars.append(env_vars[var].name)

analysis_vars
# Out:
# ['elevation',
#  'winter temperature',
#  'quarry dist',
#  'lichenbryophyte heath dist',
#  'fen dist',
#  'mosaic dist',
#  'blanket bog dist',
#  'wet heath dist',
#  'planted coniferous woodland dist',
#  'natural rock exposure dist',
#  'planted broadleaved woodland dist',
#  'acidneutral scree dist',
#  'improved grassland dist',
#  'flush and spring dist',
#  'ephemeralshort perennial dist',
#  'unimproved calcareous grassland dist',
#  'spoil dist',
#  'upland species rich ledges dist',
#  'basin mire dist',
#  'bare ground dist',
#  'semi natural broadleaved woodland dist',
#  'marshy grassland juncus dominated dist',
#  'swamp dist',
#  'basic dry heathcalcareous grassland mosaic dist',
#  'semi improved neutral grassland dist',
#  'semi improved acid grassland dist',
#  'track not comprehensively digitised dist',
#  'scree dist',
#  'wet heathacid grassland mosaic dist',
#  'dry modified bog dist',
#  'non ruderal herb and fern dist',
#  'marshy grassland molinia dominated dist',
#  'marshy grassland dist',
#  'other rock exposure dist',
#  'dry acid heath dist',
#  'buildings dist',
#  'dense scrub dist',
#  'standing water dist',
#  'acidneutral rock dist',
#  'unimproved acid grassland dist',
#  'running water dist',
#  'gardens dist',
#  'acidneutral flush dist',
#  'brophyte dominated spring dist',
#  'bare peat dist',
#  'amenity grassland dist',
#  'bracken dist',
#  'wet modified bog dist']

# %% [markdown]
# ## 3. Extract Image Data Values for Sighting Data

# %%
presence_env_var_vec_lyr = "Chrysolina_cerealis_osgb_env_vars"
presence_env_var_vec_file = os.path.join(out_dir, f"{presence_env_var_vec_lyr}.gpkg")

species_distribution.extract_env_var_data(
    env_vars=env_vars,
    smpls_vec_file=presence_sightings_vec_file,
    smpls_vec_lyr=presence_sightings_vec_lyr,
    out_vec_file=presence_env_var_vec_file,
    out_vec_lyr=presence_env_var_vec_lyr,
    out_format="GPKG",
    out_no_data_val=-9999,
    replace=True,
)
# Out:
# Deleting: sdm_LogReg_outs/Chrysolina_cerealis_osgb_env_vars.gpkg
# Processing 'elevation':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 21479.63it/s]
# Processing 'winter temperature':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 26940.26it/s]
# Processing 'quarry dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 24606.69it/s]
# Processing 'lichenbryophyte heath dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 25195.47it/s]
# Processing 'fen dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 25630.18it/s]
# Processing 'mosaic dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29943.14it/s]
# Processing 'blanket bog dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 26368.12it/s]
# Processing 'wet heath dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 25363.19it/s]
# Processing 'planted coniferous woodland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 26615.59it/s]
# Processing 'natural rock exposure dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27849.69it/s]
# Processing 'planted broadleaved woodland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29919.80it/s]
# Processing 'acidneutral scree dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 26880.77it/s]
# Processing 'improved grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28020.11it/s]
# Processing 'flush and spring dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 31306.67it/s]
# Processing 'ephemeralshort perennial dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 30490.05it/s]
# Processing 'unimproved calcareous grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29498.95it/s]
# Processing 'spoil dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 30806.21it/s]
# Processing 'upland species rich ledges dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28884.39it/s]
# Processing 'basin mire dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29132.21it/s]
# Processing 'bare ground dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 32205.59it/s]
# Processing 'semi natural broadleaved woodland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27591.05it/s]
# Processing 'marshy grassland juncus dominated dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29260.30it/s]
# Processing 'swamp dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 31514.22it/s]
# Processing 'basic dry heathcalcareous grassland mosaic dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 30013.36it/s]
# Processing 'semi improved neutral grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 31111.52it/s]
# Processing 'semi improved acid grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27913.55it/s]
# Processing 'track not comprehensively digitised dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29462.38it/s]
# Processing 'scree dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27502.88it/s]
# Processing 'wet heathacid grassland mosaic dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27557.54it/s]
# Processing 'dry modified bog dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28931.26it/s]
# Processing 'non ruderal herb and fern dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29907.25it/s]
# Processing 'marshy grassland molinia dominated dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29617.98it/s]
# Processing 'marshy grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27947.94it/s]
# Processing 'other rock exposure dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28757.90it/s]
# Processing 'dry acid heath dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 30749.27it/s]
# Processing 'buildings dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29521.63it/s]
# Processing 'dense scrub dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 26973.74it/s]
# Processing 'standing water dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29030.55it/s]
# Processing 'acidneutral rock dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29778.78it/s]
# Processing 'unimproved acid grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 36581.81it/s]
# Processing 'running water dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28312.56it/s]
# Processing 'gardens dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 31127.05it/s]
# Processing 'acidneutral flush dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 27919.80it/s]
# Processing 'brophyte dominated spring dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28124.31it/s]
# Processing 'bare peat dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 31640.07it/s]
# Processing 'amenity grassland dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 29734.43it/s]
# Processing 'bracken dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 28320.60it/s]
# Processing 'wet modified bog dist':
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 30412.03it/s]

# %%
absences_env_var_vec_lyr = "pseudo_absences_env_var"
absences_env_var_vec_file = os.path.join(out_dir, f"{absences_env_var_vec_lyr}.gpkg")

species_distribution.extract_env_var_data(
    env_vars=env_vars,
    smpls_vec_file=pseudo_absences_vec_file,
    smpls_vec_lyr=pseudo_absences_vec_lyr,
    out_vec_file=absences_env_var_vec_file,
    out_vec_lyr=absences_env_var_vec_lyr,
    out_format="GPKG",
    out_no_data_val=-9999,
    replace=True,
)
# Out:
# Deleting: sdm_LogReg_outs/pseudo_absences_env_var.gpkg
# Processing 'elevation':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 40489.08it/s]
# Processing 'winter temperature':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 48918.87it/s]
# Processing 'quarry dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50779.11it/s]
# Processing 'lichenbryophyte heath dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 49947.65it/s]
# Processing 'fen dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52046.26it/s]
# Processing 'mosaic dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51456.28it/s]
# Processing 'blanket bog dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 45994.21it/s]
# Processing 'wet heath dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50255.86it/s]
# Processing 'planted coniferous woodland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50330.04it/s]
# Processing 'natural rock exposure dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51273.86it/s]
# Processing 'planted broadleaved woodland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50443.23it/s]
# Processing 'acidneutral scree dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 46229.94it/s]
# Processing 'improved grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 49986.94it/s]
# Processing 'flush and spring dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51856.43it/s]
# Processing 'ephemeralshort perennial dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 53186.04it/s]
# Processing 'unimproved calcareous grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 46633.43it/s]
# Processing 'spoil dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 49883.49it/s]
# Processing 'upland species rich ledges dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 48971.42it/s]
# Processing 'basin mire dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 47623.58it/s]
# Processing 'bare ground dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50266.10it/s]
# Processing 'semi natural broadleaved woodland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 49507.84it/s]
# Processing 'marshy grassland juncus dominated dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 48320.92it/s]
# Processing 'swamp dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 49280.40it/s]
# Processing 'basic dry heathcalcareous grassland mosaic dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50234.19it/s]
# Processing 'semi improved neutral grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50828.34it/s]
# Processing 'semi improved acid grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 49384.84it/s]
# Processing 'track not comprehensively digitised dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50258.87it/s]
# Processing 'scree dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51002.02it/s]
# Processing 'wet heathacid grassland mosaic dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51044.23it/s]
# Processing 'dry modified bog dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51891.08it/s]
# Processing 'non ruderal herb and fern dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 53459.23it/s]
# Processing 'marshy grassland molinia dominated dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52034.64it/s]
# Processing 'marshy grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51921.27it/s]
# Processing 'other rock exposure dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52306.53it/s]
# Processing 'dry acid heath dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52941.00it/s]
# Processing 'buildings dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52496.39it/s]
# Processing 'dense scrub dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52899.61it/s]
# Processing 'standing water dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 50975.98it/s]
# Processing 'acidneutral rock dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 53774.51it/s]
# Processing 'unimproved acid grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 56072.83it/s]
# Processing 'running water dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51440.50it/s]
# Processing 'gardens dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 54513.96it/s]
# Processing 'acidneutral flush dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51725.34it/s]
# Processing 'brophyte dominated spring dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52957.72it/s]
# Processing 'bare peat dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 54039.86it/s]
# Processing 'amenity grassland dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 53544.53it/s]
# Processing 'bracken dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 51722.78it/s]
# Processing 'wet modified bog dist':
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 52974.44it/s]

# %%
# Remove any points which have invalid values from the input images

drop_atts = dict()
for var in analysis_vars:
    drop_atts[var] = -9999

presence_env_var_vld_vec_lyr = "Chrysolina_cerealis_osgb_env_vars_vld"
presence_env_var_vld_vec_file = os.path.join(
    out_dir, f"{presence_env_var_vec_lyr}.gpkg"
)

rsgislib.vectorutils.drop_rows_by_multi_attributes(
    vec_file=presence_env_var_vec_file,
    vec_lyr=presence_env_var_vec_lyr,
    drop_atts=drop_atts,
    out_vec_file=presence_env_var_vld_vec_file,
    out_vec_lyr=presence_env_var_vld_vec_lyr,
    out_format="GPKG",
)

absences_env_var_vld_vec_lyr = "pseudo_absences_env_var_vld"
absences_env_var_vld_vec_file = os.path.join(
    out_dir, f"{absences_env_var_vld_vec_lyr}.gpkg"
)

rsgislib.vectorutils.drop_rows_by_multi_attributes(
    vec_file=absences_env_var_vec_file,
    vec_lyr=absences_env_var_vec_lyr,
    drop_atts=drop_atts,
    out_vec_file=absences_env_var_vld_vec_file,
    out_vec_lyr=absences_env_var_vld_vec_lyr,
    out_format="GPKG",
)
# Out:
# elevation
# winter temperature
# quarry dist
# lichenbryophyte heath dist
# fen dist
# mosaic dist
# blanket bog dist
# wet heath dist
# planted coniferous woodland dist
# natural rock exposure dist
# planted broadleaved woodland dist
# acidneutral scree dist
# improved grassland dist
# flush and spring dist
# ephemeralshort perennial dist
# unimproved calcareous grassland dist
# spoil dist
# upland species rich ledges dist
# basin mire dist
# bare ground dist
# semi natural broadleaved woodland dist
# marshy grassland juncus dominated dist
# swamp dist
# basic dry heathcalcareous grassland mosaic dist
# semi improved neutral grassland dist
# semi improved acid grassland dist
# track not comprehensively digitised dist
# scree dist
# wet heathacid grassland mosaic dist
# dry modified bog dist
# non ruderal herb and fern dist
# marshy grassland molinia dominated dist
# marshy grassland dist
# other rock exposure dist
# dry acid heath dist
# buildings dist
# dense scrub dist
# standing water dist
# acidneutral rock dist
# unimproved acid grassland dist
# running water dist
# gardens dist
# acidneutral flush dist
# brophyte dominated spring dist
# bare peat dist
# amenity grassland dist
# bracken dist
# wet modified bog dist
# elevation
# winter temperature
# quarry dist
# lichenbryophyte heath dist
# fen dist
# mosaic dist
# blanket bog dist
# wet heath dist
# planted coniferous woodland dist
# natural rock exposure dist
# planted broadleaved woodland dist
# acidneutral scree dist
# improved grassland dist
# flush and spring dist
# ephemeralshort perennial dist
# unimproved calcareous grassland dist
# spoil dist
# upland species rich ledges dist
# basin mire dist
# bare ground dist
# semi natural broadleaved woodland dist
# marshy grassland juncus dominated dist
# swamp dist
# basic dry heathcalcareous grassland mosaic dist
# semi improved neutral grassland dist
# semi improved acid grassland dist
# track not comprehensively digitised dist
# scree dist
# wet heathacid grassland mosaic dist
# dry modified bog dist
# non ruderal herb and fern dist
# marshy grassland molinia dominated dist
# marshy grassland dist
# other rock exposure dist
# dry acid heath dist
# buildings dist
# dense scrub dist
# standing water dist
# acidneutral rock dist
# unimproved acid grassland dist
# running water dist
# gardens dist
# acidneutral flush dist
# brophyte dominated spring dist
# bare peat dist
# amenity grassland dist
# bracken dist
# wet modified bog dist

# %% [markdown]
# ## 4. How Many Samples Are Left?

# %%
n_presence_pts = rsgislib.vectorutils.get_vec_feat_count(
    vec_file=presence_env_var_vec_file, vec_lyr=presence_env_var_vec_lyr
)
n_absence_pts = rsgislib.vectorutils.get_vec_feat_count(
    vec_file=absences_env_var_vec_file,
    vec_lyr=absences_env_var_vec_lyr,
)

print(f"There are {n_presence_pts} presences points")
print(f"There are {n_absence_pts} absence points")
# Out:
# There are 119 presences points
# There are 999 absence points

# %% [markdown]
# ## 5. Combine Presence and Absence Points
#
# Optionally, while combining the presence and absence data the number of presence and absence samples can be equalised which is important for tree based models (e.g., Random Forests)

# %%
pres_abs_vec_lyr = "presences_absences_env_var_vld"
pres_abs_vec_file = os.path.join(out_dir, f"{pres_abs_vec_lyr}.gpkg")

ana_env_vars = species_distribution.combine_presence_absence_data(
    presence_smpls_vec_file=presence_env_var_vec_file,
    presence_smpls_vec_lyr=presence_env_var_vec_lyr,
    absence_smpls_vec_file=absences_env_var_vec_file,
    absence_smpls_vec_lyr=absences_env_var_vec_lyr,
    env_vars=env_vars,
    out_vec_file=pres_abs_vec_file,
    out_vec_lyr=pres_abs_vec_lyr,
    out_format="GPKG",
    equalise_smpls=False,
    cls_col="clsid",
    rnd_seed=None,
)
# Out:
# Dropping from presence: ['Scientific name', 'Common name', 'Occurrence status', 'Year', 'Latitude (WGS84)', 'Longitude (WGS84)', 'Coordinate uncertainty (m)', 'Recorder', 'Individual count', 'Institution code']
# Dropping from absence: ['index_right', 'Scientific name', 'Common name', 'Occurrence status', 'Year', 'Latitude (WGS84)', 'Longitude (WGS84)', 'Coordinate uncertainty (m)', 'Recorder', 'Individual count', 'Institution code', 'presents_dist', 'dist_sel']

# %% [markdown]
# ## 6. Create Comparison Plots

# %%
species_distribution.comparison_box_plots(
    env_vars=env_vars,
    vec_file=pres_abs_vec_file,
    vec_lyr=pres_abs_vec_lyr,
    out_dir=os.path.join(out_dir, "boxplots"),
    cls_col="clsid",
    box_plots=True,
)

# %% [markdown]
# ## 7. Calculate the Correlation Matrix

# %%
species_distribution.correlation_matrix(
    env_vars=env_vars,
    vec_file=pres_abs_vec_file,
    vec_lyr=pres_abs_vec_lyr,
    out_corr_file=os.path.join(out_dir, "correlation_matrix.csv"),
    out_plt_file=os.path.join(out_dir, "correlation_matrix.png"),
)

# %% [markdown]
# ## 8. Remove Correlated Variables
#
# Note. that removing highly correlated variables can improve the outputs.
#
# In this case, you can see that elevation and winter temperature are highly negatively correlated and therefore one should be removed. We'll remove 'elevation'.

# %%
analysis_vars.remove("elevation")

# %% [markdown]
# ## 9. Standardise Environmental Variables
#
# Some models (e.g., SVM and Logistic Regression) require that the variables are standardised to the same range. However, if you are using a model such as Random Forests you do not need to worry about this step.

# %%
# Optionally: Standardise the continious data using mean and stdev from sample data
species_distribution.pop_normalise_coeffs(
    env_vars=env_vars,
    vec_file=pres_abs_vec_file,
    vec_lyr=pres_abs_vec_lyr,
)

# %%
pres_abs_std_vec_lyr = "presences_absences_env_var_vld_std"
pres_abs_std_vec_file = os.path.join(out_dir, f"{pres_abs_std_vec_lyr}.gpkg")

species_distribution.apply_normalise_coeffs(
    env_vars=env_vars,
    vec_file=pres_abs_vec_file,
    vec_lyr=pres_abs_vec_lyr,
    out_vec_file=pres_abs_std_vec_file,
    out_vec_lyr=pres_abs_std_vec_lyr,
    out_format="GPKG",
)

# %% [markdown]
# ## 10. Create Training and Testing Datasets

# %%
pres_abs_std_train_vec_lyr = "presences_absences_env_var_vld_std_train"
pres_abs_std_train_vec_file = os.path.join(
    out_dir, f"{pres_abs_std_train_vec_lyr}.gpkg"
)

pres_abs_std_test_vec_lyr = "presences_absences_env_var_vld_std_test"
pres_abs_std_test_vec_file = os.path.join(out_dir, f"{pres_abs_std_test_vec_lyr}.gpkg")

species_distribution.create_train_test_sets(
    vec_file=pres_abs_std_vec_file,
    vec_lyr=pres_abs_std_vec_lyr,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    test_vec_file=pres_abs_std_test_vec_file,
    test_vec_lyr=pres_abs_std_test_vec_lyr,
    split_prop=0.8,
    cls_col="clsid",
    out_format="GPKG",
    rnd_seed=None,
)

# %% [markdown]
# ## 11. Find Optimal Model Parameters (GridSearch)

# %%
lr = LogisticRegression(
    solver="liblinear",
    max_iter=500,
    penalty="l2",
    tol=0.0001,
    C=0.1,
    fit_intercept=True,
    intercept_scaling=1,
)

grid_space = {
    "max_iter": [100, 250, 500, 750],
    "penalty": ["l1", "l2"],
    "C": [0.1, 0.5, 1, 1.5],
    "tol": [0.001, 0.0001, 0.0005],
}
search_obj = GridSearchCV(
    lr, param_grid=grid_space, cv=5, scoring="accuracy", verbose=10
)


# Fit model - what about parameter optimisation (i.e., grid search)?
opt_skl_mdl, opt_mdl_params = species_distribution.search_mdl_params(
    search_obj=search_obj,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    analysis_vars=analysis_vars,
    cls_col="clsid",
)

mdl_params_file = os.path.join(out_dir, "lr_mdl_params.json")

rsgislib.tools.utils.write_dict_to_json(opt_mdl_params, out_file=mdl_params_file)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5; 1/96] START C=0.1, max_iter=100, penalty=l1, tol=0.001.................
# [CV 1/5; 1/96] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=0.922 total time=   0.0s
# [CV 2/5; 1/96] START C=0.1, max_iter=100, penalty=l1, tol=0.001.................
# [CV 2/5; 1/96] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=0.939 total time=   0.0s
# [CV 3/5; 1/96] START C=0.1, max_iter=100, penalty=l1, tol=0.001.................
# [CV 3/5; 1/96] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=0.927 total time=   0.0s
# [CV 4/5; 1/96] START C=0.1, max_iter=100, penalty=l1, tol=0.001.................
# [CV 4/5; 1/96] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 5/5; 1/96] START C=0.1, max_iter=100, penalty=l1, tol=0.001.................
# [CV 5/5; 1/96] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 1/5; 2/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0001................
# [CV 1/5; 2/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=0.922 total time=   0.0s
# [CV 2/5; 2/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0001................
# [CV 2/5; 2/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 3/5; 2/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0001................
# [CV 3/5; 2/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 4/5; 2/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0001................
# [CV 4/5; 2/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 5/5; 2/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0001................
# [CV 5/5; 2/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 1/5; 3/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0005................
# [CV 1/5; 3/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0005;, score=0.922 total time=   0.0s
# [CV 2/5; 3/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0005................
# [CV 2/5; 3/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 3/5; 3/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0005................
# [CV 3/5; 3/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 4/5; 3/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0005................
# [CV 4/5; 3/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 5/5; 3/96] START C=0.1, max_iter=100, penalty=l1, tol=0.0005................
# [CV 5/5; 3/96] END C=0.1, max_iter=100, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 1/5; 4/96] START C=0.1, max_iter=100, penalty=l2, tol=0.001.................
# [CV 1/5; 4/96] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.916 total time=   0.0s
# [CV 2/5; 4/96] START C=0.1, max_iter=100, penalty=l2, tol=0.001.................
# [CV 2/5; 4/96] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.944 total time=   0.0s
# [CV 3/5; 4/96] START C=0.1, max_iter=100, penalty=l2, tol=0.001.................
# [CV 3/5; 4/96] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.939 total time=   0.0s
# [CV 4/5; 4/96] START C=0.1, max_iter=100, penalty=l2, tol=0.001.................
# [CV 4/5; 4/96] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.927 total time=   0.0s
# [CV 5/5; 4/96] START C=0.1, max_iter=100, penalty=l2, tol=0.001.................
# [CV 5/5; 4/96] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.921 total time=   0.0s
# [CV 1/5; 5/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0001................
# [CV 1/5; 5/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 2/5; 5/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0001................
# [CV 2/5; 5/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 3/5; 5/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0001................
# [CV 3/5; 5/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 4/5; 5/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0001................
# [CV 4/5; 5/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 5/5; 5/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0001................
# [CV 5/5; 5/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.921 total time=   0.0s
# [CV 1/5; 6/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0005................
# [CV 1/5; 6/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 2/5; 6/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0005................
# [CV 2/5; 6/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 3/5; 6/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0005................
# [CV 3/5; 6/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 4/5; 6/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0005................
# [CV 4/5; 6/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 5/5; 6/96] START C=0.1, max_iter=100, penalty=l2, tol=0.0005................
# [CV 5/5; 6/96] END C=0.1, max_iter=100, penalty=l2, tol=0.0005;, score=0.921 total time=   0.0s
# [CV 1/5; 7/96] START C=0.1, max_iter=250, penalty=l1, tol=0.001.................
# [CV 1/5; 7/96] END C=0.1, max_iter=250, penalty=l1, tol=0.001;, score=0.922 total time=   0.0s
# [CV 2/5; 7/96] START C=0.1, max_iter=250, penalty=l1, tol=0.001.................
# [CV 2/5; 7/96] END C=0.1, max_iter=250, penalty=l1, tol=0.001;, score=0.939 total time=   0.0s
# [CV 3/5; 7/96] START C=0.1, max_iter=250, penalty=l1, tol=0.001.................
# [CV 3/5; 7/96] END C=0.1, max_iter=250, penalty=l1, tol=0.001;, score=0.927 total time=   0.0s
# [CV 4/5; 7/96] START C=0.1, max_iter=250, penalty=l1, tol=0.001.................
# [CV 4/5; 7/96] END C=0.1, max_iter=250, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 5/5; 7/96] START C=0.1, max_iter=250, penalty=l1, tol=0.001.................
# [CV 5/5; 7/96] END C=0.1, max_iter=250, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 1/5; 8/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0001................
# [CV 1/5; 8/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0001;, score=0.922 total time=   0.0s
# [CV 2/5; 8/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0001................
# [CV 2/5; 8/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 3/5; 8/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0001................
# [CV 3/5; 8/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 4/5; 8/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0001................
# [CV 4/5; 8/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 5/5; 8/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0001................
# [CV 5/5; 8/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 1/5; 9/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0005................
# [CV 1/5; 9/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0005;, score=0.922 total time=   0.0s
# [CV 2/5; 9/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0005................
# [CV 2/5; 9/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 3/5; 9/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0005................
# [CV 3/5; 9/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 4/5; 9/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0005................
# [CV 4/5; 9/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 5/5; 9/96] START C=0.1, max_iter=250, penalty=l1, tol=0.0005................
# [CV 5/5; 9/96] END C=0.1, max_iter=250, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 1/5; 10/96] START C=0.1, max_iter=250, penalty=l2, tol=0.001................
# [CV 1/5; 10/96] END C=0.1, max_iter=250, penalty=l2, tol=0.001;, score=0.916 total time=   0.0s
# [CV 2/5; 10/96] START C=0.1, max_iter=250, penalty=l2, tol=0.001................
# [CV 2/5; 10/96] END C=0.1, max_iter=250, penalty=l2, tol=0.001;, score=0.944 total time=   0.0s
# [CV 3/5; 10/96] START C=0.1, max_iter=250, penalty=l2, tol=0.001................
# [CV 3/5; 10/96] END C=0.1, max_iter=250, penalty=l2, tol=0.001;, score=0.939 total time=   0.0s
# [CV 4/5; 10/96] START C=0.1, max_iter=250, penalty=l2, tol=0.001................
# [CV 4/5; 10/96] END C=0.1, max_iter=250, penalty=l2, tol=0.001;, score=0.927 total time=   0.0s
# [CV 5/5; 10/96] START C=0.1, max_iter=250, penalty=l2, tol=0.001................
# [CV 5/5; 10/96] END C=0.1, max_iter=250, penalty=l2, tol=0.001;, score=0.921 total time=   0.0s
# [CV 1/5; 11/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 1/5; 11/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 2/5; 11/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 2/5; 11/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 3/5; 11/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 3/5; 11/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 4/5; 11/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 4/5; 11/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 5/5; 11/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 5/5; 11/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0001;, score=0.921 total time=   0.0s
# [CV 1/5; 12/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 1/5; 12/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 2/5; 12/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 2/5; 12/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 3/5; 12/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 3/5; 12/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 4/5; 12/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 4/5; 12/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 5/5; 12/96] START C=0.1, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 5/5; 12/96] END C=0.1, max_iter=250, penalty=l2, tol=0.0005;, score=0.921 total time=   0.0s
# [CV 1/5; 13/96] START C=0.1, max_iter=500, penalty=l1, tol=0.001................
# [CV 1/5; 13/96] END C=0.1, max_iter=500, penalty=l1, tol=0.001;, score=0.922 total time=   0.0s
# [CV 2/5; 13/96] START C=0.1, max_iter=500, penalty=l1, tol=0.001................
# [CV 2/5; 13/96] END C=0.1, max_iter=500, penalty=l1, tol=0.001;, score=0.939 total time=   0.0s
# [CV 3/5; 13/96] START C=0.1, max_iter=500, penalty=l1, tol=0.001................
# [CV 3/5; 13/96] END C=0.1, max_iter=500, penalty=l1, tol=0.001;, score=0.927 total time=   0.0s
# [CV 4/5; 13/96] START C=0.1, max_iter=500, penalty=l1, tol=0.001................
# [CV 4/5; 13/96] END C=0.1, max_iter=500, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 5/5; 13/96] START C=0.1, max_iter=500, penalty=l1, tol=0.001................
# [CV 5/5; 13/96] END C=0.1, max_iter=500, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 1/5; 14/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 1/5; 14/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0001;, score=0.922 total time=   0.0s
# [CV 2/5; 14/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 2/5; 14/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 3/5; 14/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 3/5; 14/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 4/5; 14/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 4/5; 14/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 5/5; 14/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 5/5; 14/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 1/5; 15/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 1/5; 15/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0005;, score=0.922 total time=   0.0s
# [CV 2/5; 15/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 2/5; 15/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 3/5; 15/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 3/5; 15/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 4/5; 15/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 4/5; 15/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 5/5; 15/96] START C=0.1, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 5/5; 15/96] END C=0.1, max_iter=500, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 1/5; 16/96] START C=0.1, max_iter=500, penalty=l2, tol=0.001................
# [CV 1/5; 16/96] END C=0.1, max_iter=500, penalty=l2, tol=0.001;, score=0.916 total time=   0.0s
# [CV 2/5; 16/96] START C=0.1, max_iter=500, penalty=l2, tol=0.001................
# [CV 2/5; 16/96] END C=0.1, max_iter=500, penalty=l2, tol=0.001;, score=0.944 total time=   0.0s
# [CV 3/5; 16/96] START C=0.1, max_iter=500, penalty=l2, tol=0.001................
# [CV 3/5; 16/96] END C=0.1, max_iter=500, penalty=l2, tol=0.001;, score=0.939 total time=   0.0s
# [CV 4/5; 16/96] START C=0.1, max_iter=500, penalty=l2, tol=0.001................
# [CV 4/5; 16/96] END C=0.1, max_iter=500, penalty=l2, tol=0.001;, score=0.927 total time=   0.0s
# [CV 5/5; 16/96] START C=0.1, max_iter=500, penalty=l2, tol=0.001................
# [CV 5/5; 16/96] END C=0.1, max_iter=500, penalty=l2, tol=0.001;, score=0.921 total time=   0.0s
# [CV 1/5; 17/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 1/5; 17/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 2/5; 17/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 2/5; 17/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 3/5; 17/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 3/5; 17/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 4/5; 17/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 4/5; 17/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 5/5; 17/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 5/5; 17/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0001;, score=0.921 total time=   0.0s
# [CV 1/5; 18/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 1/5; 18/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 2/5; 18/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 2/5; 18/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 3/5; 18/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 3/5; 18/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 4/5; 18/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 4/5; 18/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 5/5; 18/96] START C=0.1, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 5/5; 18/96] END C=0.1, max_iter=500, penalty=l2, tol=0.0005;, score=0.921 total time=   0.0s
# [CV 1/5; 19/96] START C=0.1, max_iter=750, penalty=l1, tol=0.001................
# [CV 1/5; 19/96] END C=0.1, max_iter=750, penalty=l1, tol=0.001;, score=0.922 total time=   0.0s
# [CV 2/5; 19/96] START C=0.1, max_iter=750, penalty=l1, tol=0.001................
# [CV 2/5; 19/96] END C=0.1, max_iter=750, penalty=l1, tol=0.001;, score=0.939 total time=   0.0s
# [CV 3/5; 19/96] START C=0.1, max_iter=750, penalty=l1, tol=0.001................
# [CV 3/5; 19/96] END C=0.1, max_iter=750, penalty=l1, tol=0.001;, score=0.927 total time=   0.0s
# [CV 4/5; 19/96] START C=0.1, max_iter=750, penalty=l1, tol=0.001................
# [CV 4/5; 19/96] END C=0.1, max_iter=750, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 5/5; 19/96] START C=0.1, max_iter=750, penalty=l1, tol=0.001................
# [CV 5/5; 19/96] END C=0.1, max_iter=750, penalty=l1, tol=0.001;, score=0.916 total time=   0.0s
# [CV 1/5; 20/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 1/5; 20/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0001;, score=0.922 total time=   0.0s
# [CV 2/5; 20/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 2/5; 20/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 3/5; 20/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 3/5; 20/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 4/5; 20/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 4/5; 20/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 5/5; 20/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 5/5; 20/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 1/5; 21/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 1/5; 21/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0005;, score=0.922 total time=   0.0s
# [CV 2/5; 21/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 2/5; 21/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 3/5; 21/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 3/5; 21/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 4/5; 21/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 4/5; 21/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 5/5; 21/96] START C=0.1, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 5/5; 21/96] END C=0.1, max_iter=750, penalty=l1, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 1/5; 22/96] START C=0.1, max_iter=750, penalty=l2, tol=0.001................
# [CV 1/5; 22/96] END C=0.1, max_iter=750, penalty=l2, tol=0.001;, score=0.916 total time=   0.0s
# [CV 2/5; 22/96] START C=0.1, max_iter=750, penalty=l2, tol=0.001................
# [CV 2/5; 22/96] END C=0.1, max_iter=750, penalty=l2, tol=0.001;, score=0.944 total time=   0.0s
# [CV 3/5; 22/96] START C=0.1, max_iter=750, penalty=l2, tol=0.001................
# [CV 3/5; 22/96] END C=0.1, max_iter=750, penalty=l2, tol=0.001;, score=0.939 total time=   0.0s
# [CV 4/5; 22/96] START C=0.1, max_iter=750, penalty=l2, tol=0.001................
# [CV 4/5; 22/96] END C=0.1, max_iter=750, penalty=l2, tol=0.001;, score=0.927 total time=   0.0s
# [CV 5/5; 22/96] START C=0.1, max_iter=750, penalty=l2, tol=0.001................
# [CV 5/5; 22/96] END C=0.1, max_iter=750, penalty=l2, tol=0.001;, score=0.921 total time=   0.0s
# [CV 1/5; 23/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 1/5; 23/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0001;, score=0.916 total time=   0.0s
# [CV 2/5; 23/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 2/5; 23/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 3/5; 23/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 3/5; 23/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0001;, score=0.939 total time=   0.0s
# [CV 4/5; 23/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 4/5; 23/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0001;, score=0.927 total time=   0.0s
# [CV 5/5; 23/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 5/5; 23/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0001;, score=0.921 total time=   0.0s
# [CV 1/5; 24/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 1/5; 24/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0005;, score=0.916 total time=   0.0s
# [CV 2/5; 24/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 2/5; 24/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 3/5; 24/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 3/5; 24/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0005;, score=0.939 total time=   0.0s
# [CV 4/5; 24/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 4/5; 24/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0005;, score=0.927 total time=   0.0s
# [CV 5/5; 24/96] START C=0.1, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 5/5; 24/96] END C=0.1, max_iter=750, penalty=l2, tol=0.0005;, score=0.921 total time=   0.0s
# [CV 1/5; 25/96] START C=0.5, max_iter=100, penalty=l1, tol=0.001................
# [CV 1/5; 25/96] END C=0.5, max_iter=100, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 2/5; 25/96] START C=0.5, max_iter=100, penalty=l1, tol=0.001................
# [CV 2/5; 25/96] END C=0.5, max_iter=100, penalty=l1, tol=0.001;, score=0.966 total time=   0.0s
# [CV 3/5; 25/96] START C=0.5, max_iter=100, penalty=l1, tol=0.001................
# [CV 3/5; 25/96] END C=0.5, max_iter=100, penalty=l1, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 25/96] START C=0.5, max_iter=100, penalty=l1, tol=0.001................
# [CV 4/5; 25/96] END C=0.5, max_iter=100, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 5/5; 25/96] START C=0.5, max_iter=100, penalty=l1, tol=0.001................
# [CV 5/5; 25/96] END C=0.5, max_iter=100, penalty=l1, tol=0.001;, score=0.944 total time=   0.0s
# [CV 1/5; 26/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 1/5; 26/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 2/5; 26/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 2/5; 26/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 26/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 3/5; 26/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 26/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 4/5; 26/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 5/5; 26/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 5/5; 26/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 1/5; 27/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0005...............
# [CV 1/5; 27/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 2/5; 27/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0005...............
# [CV 2/5; 27/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 27/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0005...............
# [CV 3/5; 27/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 27/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0005...............
# [CV 4/5; 27/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 5/5; 27/96] START C=0.5, max_iter=100, penalty=l1, tol=0.0005...............
# [CV 5/5; 27/96] END C=0.5, max_iter=100, penalty=l1, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 1/5; 28/96] START C=0.5, max_iter=100, penalty=l2, tol=0.001................
# [CV 1/5; 28/96] END C=0.5, max_iter=100, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 2/5; 28/96] START C=0.5, max_iter=100, penalty=l2, tol=0.001................
# [CV 2/5; 28/96] END C=0.5, max_iter=100, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 3/5; 28/96] START C=0.5, max_iter=100, penalty=l2, tol=0.001................
# [CV 3/5; 28/96] END C=0.5, max_iter=100, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 28/96] START C=0.5, max_iter=100, penalty=l2, tol=0.001................
# [CV 4/5; 28/96] END C=0.5, max_iter=100, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 5/5; 28/96] START C=0.5, max_iter=100, penalty=l2, tol=0.001................
# [CV 5/5; 28/96] END C=0.5, max_iter=100, penalty=l2, tol=0.001;, score=0.949 total time=   0.0s
# [CV 1/5; 29/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 1/5; 29/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 2/5; 29/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 2/5; 29/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 29/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 3/5; 29/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 29/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 4/5; 29/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 5/5; 29/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 5/5; 29/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0001;, score=0.949 total time=   0.0s
# [CV 1/5; 30/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0005...............
# [CV 1/5; 30/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 2/5; 30/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0005...............
# [CV 2/5; 30/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 30/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0005...............
# [CV 3/5; 30/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 30/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0005...............
# [CV 4/5; 30/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 5/5; 30/96] START C=0.5, max_iter=100, penalty=l2, tol=0.0005...............
# [CV 5/5; 30/96] END C=0.5, max_iter=100, penalty=l2, tol=0.0005;, score=0.949 total time=   0.0s
# [CV 1/5; 31/96] START C=0.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 1/5; 31/96] END C=0.5, max_iter=250, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 2/5; 31/96] START C=0.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 2/5; 31/96] END C=0.5, max_iter=250, penalty=l1, tol=0.001;, score=0.972 total time=   0.0s
# [CV 3/5; 31/96] START C=0.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 3/5; 31/96] END C=0.5, max_iter=250, penalty=l1, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 31/96] START C=0.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 4/5; 31/96] END C=0.5, max_iter=250, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 5/5; 31/96] START C=0.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 5/5; 31/96] END C=0.5, max_iter=250, penalty=l1, tol=0.001;, score=0.944 total time=   0.0s
# [CV 1/5; 32/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 1/5; 32/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 2/5; 32/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 2/5; 32/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 32/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 3/5; 32/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 32/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 4/5; 32/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 5/5; 32/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 5/5; 32/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 1/5; 33/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 1/5; 33/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 2/5; 33/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 2/5; 33/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 33/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 3/5; 33/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 33/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 4/5; 33/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 5/5; 33/96] START C=0.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 5/5; 33/96] END C=0.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 1/5; 34/96] START C=0.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 1/5; 34/96] END C=0.5, max_iter=250, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 2/5; 34/96] START C=0.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 2/5; 34/96] END C=0.5, max_iter=250, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 3/5; 34/96] START C=0.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 3/5; 34/96] END C=0.5, max_iter=250, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 34/96] START C=0.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 4/5; 34/96] END C=0.5, max_iter=250, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 5/5; 34/96] START C=0.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 5/5; 34/96] END C=0.5, max_iter=250, penalty=l2, tol=0.001;, score=0.949 total time=   0.0s
# [CV 1/5; 35/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 1/5; 35/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 2/5; 35/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 2/5; 35/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 35/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 3/5; 35/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 35/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 4/5; 35/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 5/5; 35/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 5/5; 35/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.949 total time=   0.0s
# [CV 1/5; 36/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 1/5; 36/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 2/5; 36/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 2/5; 36/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 36/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 3/5; 36/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 36/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 4/5; 36/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 5/5; 36/96] START C=0.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 5/5; 36/96] END C=0.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.949 total time=   0.0s
# [CV 1/5; 37/96] START C=0.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 1/5; 37/96] END C=0.5, max_iter=500, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 2/5; 37/96] START C=0.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 2/5; 37/96] END C=0.5, max_iter=500, penalty=l1, tol=0.001;, score=0.966 total time=   0.0s
# [CV 3/5; 37/96] START C=0.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 3/5; 37/96] END C=0.5, max_iter=500, penalty=l1, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 37/96] START C=0.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 4/5; 37/96] END C=0.5, max_iter=500, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 5/5; 37/96] START C=0.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 5/5; 37/96] END C=0.5, max_iter=500, penalty=l1, tol=0.001;, score=0.944 total time=   0.0s
# [CV 1/5; 38/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 1/5; 38/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 2/5; 38/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 2/5; 38/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 38/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 3/5; 38/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 38/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 4/5; 38/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 5/5; 38/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 5/5; 38/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 1/5; 39/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 1/5; 39/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 2/5; 39/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 2/5; 39/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 39/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 3/5; 39/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 39/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 4/5; 39/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 5/5; 39/96] START C=0.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 5/5; 39/96] END C=0.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 1/5; 40/96] START C=0.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 1/5; 40/96] END C=0.5, max_iter=500, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 2/5; 40/96] START C=0.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 2/5; 40/96] END C=0.5, max_iter=500, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 3/5; 40/96] START C=0.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 3/5; 40/96] END C=0.5, max_iter=500, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 40/96] START C=0.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 4/5; 40/96] END C=0.5, max_iter=500, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 5/5; 40/96] START C=0.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 5/5; 40/96] END C=0.5, max_iter=500, penalty=l2, tol=0.001;, score=0.949 total time=   0.0s
# [CV 1/5; 41/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 1/5; 41/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 2/5; 41/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 2/5; 41/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 41/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 3/5; 41/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 41/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 4/5; 41/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 5/5; 41/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 5/5; 41/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.949 total time=   0.0s
# [CV 1/5; 42/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 1/5; 42/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 2/5; 42/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 2/5; 42/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 42/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 3/5; 42/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 42/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 4/5; 42/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 5/5; 42/96] START C=0.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 5/5; 42/96] END C=0.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.949 total time=   0.0s
# [CV 1/5; 43/96] START C=0.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 1/5; 43/96] END C=0.5, max_iter=750, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 2/5; 43/96] START C=0.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 2/5; 43/96] END C=0.5, max_iter=750, penalty=l1, tol=0.001;, score=0.972 total time=   0.0s
# [CV 3/5; 43/96] START C=0.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 3/5; 43/96] END C=0.5, max_iter=750, penalty=l1, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 43/96] START C=0.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 4/5; 43/96] END C=0.5, max_iter=750, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 5/5; 43/96] START C=0.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 5/5; 43/96] END C=0.5, max_iter=750, penalty=l1, tol=0.001;, score=0.944 total time=   0.0s
# [CV 1/5; 44/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 1/5; 44/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 2/5; 44/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 2/5; 44/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 44/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 3/5; 44/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 44/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 4/5; 44/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 5/5; 44/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 5/5; 44/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.944 total time=   0.0s
# [CV 1/5; 45/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 1/5; 45/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 2/5; 45/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 2/5; 45/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 45/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 3/5; 45/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 45/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 4/5; 45/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 5/5; 45/96] START C=0.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 5/5; 45/96] END C=0.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.944 total time=   0.0s
# [CV 1/5; 46/96] START C=0.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 1/5; 46/96] END C=0.5, max_iter=750, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 2/5; 46/96] START C=0.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 2/5; 46/96] END C=0.5, max_iter=750, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 3/5; 46/96] START C=0.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 3/5; 46/96] END C=0.5, max_iter=750, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 46/96] START C=0.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 4/5; 46/96] END C=0.5, max_iter=750, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 5/5; 46/96] START C=0.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 5/5; 46/96] END C=0.5, max_iter=750, penalty=l2, tol=0.001;, score=0.949 total time=   0.0s
# [CV 1/5; 47/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 1/5; 47/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 2/5; 47/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 2/5; 47/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 3/5; 47/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 3/5; 47/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 47/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 4/5; 47/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 5/5; 47/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 5/5; 47/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.949 total time=   0.0s
# [CV 1/5; 48/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 1/5; 48/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 2/5; 48/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 2/5; 48/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 3/5; 48/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 3/5; 48/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 48/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 4/5; 48/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 5/5; 48/96] START C=0.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 5/5; 48/96] END C=0.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.949 total time=   0.0s
# [CV 1/5; 49/96] START C=1, max_iter=100, penalty=l1, tol=0.001..................
# [CV 1/5; 49/96] END C=1, max_iter=100, penalty=l1, tol=0.001;, score=0.972 total time=   0.0s
# [CV 2/5; 49/96] START C=1, max_iter=100, penalty=l1, tol=0.001..................
# [CV 2/5; 49/96] END C=1, max_iter=100, penalty=l1, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 49/96] START C=1, max_iter=100, penalty=l1, tol=0.001..................
# [CV 3/5; 49/96] END C=1, max_iter=100, penalty=l1, tol=0.001;, score=0.961 total time=   0.0s
# [CV 4/5; 49/96] START C=1, max_iter=100, penalty=l1, tol=0.001..................
# [CV 4/5; 49/96] END C=1, max_iter=100, penalty=l1, tol=0.001;, score=0.972 total time=   0.0s
# [CV 5/5; 49/96] START C=1, max_iter=100, penalty=l1, tol=0.001..................
# [CV 5/5; 49/96] END C=1, max_iter=100, penalty=l1, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 50/96] START C=1, max_iter=100, penalty=l1, tol=0.0001.................
# [CV 1/5; 50/96] END C=1, max_iter=100, penalty=l1, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 2/5; 50/96] START C=1, max_iter=100, penalty=l1, tol=0.0001.................
# [CV 2/5; 50/96] END C=1, max_iter=100, penalty=l1, tol=0.0001;, score=0.994 total time=   0.1s
# [CV 3/5; 50/96] START C=1, max_iter=100, penalty=l1, tol=0.0001.................
# [CV 3/5; 50/96] END C=1, max_iter=100, penalty=l1, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 4/5; 50/96] START C=1, max_iter=100, penalty=l1, tol=0.0001.................
# [CV 4/5; 50/96] END C=1, max_iter=100, penalty=l1, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 5/5; 50/96] START C=1, max_iter=100, penalty=l1, tol=0.0001.................
# [CV 5/5; 50/96] END C=1, max_iter=100, penalty=l1, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 51/96] START C=1, max_iter=100, penalty=l1, tol=0.0005.................
# [CV 1/5; 51/96] END C=1, max_iter=100, penalty=l1, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 2/5; 51/96] START C=1, max_iter=100, penalty=l1, tol=0.0005.................
# [CV 2/5; 51/96] END C=1, max_iter=100, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 51/96] START C=1, max_iter=100, penalty=l1, tol=0.0005.................
# [CV 3/5; 51/96] END C=1, max_iter=100, penalty=l1, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 4/5; 51/96] START C=1, max_iter=100, penalty=l1, tol=0.0005.................
# [CV 4/5; 51/96] END C=1, max_iter=100, penalty=l1, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 5/5; 51/96] START C=1, max_iter=100, penalty=l1, tol=0.0005.................
# [CV 5/5; 51/96] END C=1, max_iter=100, penalty=l1, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 1/5; 52/96] START C=1, max_iter=100, penalty=l2, tol=0.001..................
# [CV 1/5; 52/96] END C=1, max_iter=100, penalty=l2, tol=0.001;, score=0.961 total time=   0.0s
# [CV 2/5; 52/96] START C=1, max_iter=100, penalty=l2, tol=0.001..................
# [CV 2/5; 52/96] END C=1, max_iter=100, penalty=l2, tol=0.001;, score=0.978 total time=   0.0s
# [CV 3/5; 52/96] START C=1, max_iter=100, penalty=l2, tol=0.001..................
# [CV 3/5; 52/96] END C=1, max_iter=100, penalty=l2, tol=0.001;, score=0.955 total time=   0.0s
# [CV 4/5; 52/96] START C=1, max_iter=100, penalty=l2, tol=0.001..................
# [CV 4/5; 52/96] END C=1, max_iter=100, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 5/5; 52/96] START C=1, max_iter=100, penalty=l2, tol=0.001..................
# [CV 5/5; 52/96] END C=1, max_iter=100, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 53/96] START C=1, max_iter=100, penalty=l2, tol=0.0001.................
# [CV 1/5; 53/96] END C=1, max_iter=100, penalty=l2, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 2/5; 53/96] START C=1, max_iter=100, penalty=l2, tol=0.0001.................
# [CV 2/5; 53/96] END C=1, max_iter=100, penalty=l2, tol=0.0001;, score=0.978 total time=   0.0s
# [CV 3/5; 53/96] START C=1, max_iter=100, penalty=l2, tol=0.0001.................
# [CV 3/5; 53/96] END C=1, max_iter=100, penalty=l2, tol=0.0001;, score=0.955 total time=   0.0s
# [CV 4/5; 53/96] START C=1, max_iter=100, penalty=l2, tol=0.0001.................
# [CV 4/5; 53/96] END C=1, max_iter=100, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 5/5; 53/96] START C=1, max_iter=100, penalty=l2, tol=0.0001.................
# [CV 5/5; 53/96] END C=1, max_iter=100, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 54/96] START C=1, max_iter=100, penalty=l2, tol=0.0005.................
# [CV 1/5; 54/96] END C=1, max_iter=100, penalty=l2, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 2/5; 54/96] START C=1, max_iter=100, penalty=l2, tol=0.0005.................
# [CV 2/5; 54/96] END C=1, max_iter=100, penalty=l2, tol=0.0005;, score=0.978 total time=   0.0s
# [CV 3/5; 54/96] START C=1, max_iter=100, penalty=l2, tol=0.0005.................
# [CV 3/5; 54/96] END C=1, max_iter=100, penalty=l2, tol=0.0005;, score=0.955 total time=   0.0s
# [CV 4/5; 54/96] START C=1, max_iter=100, penalty=l2, tol=0.0005.................
# [CV 4/5; 54/96] END C=1, max_iter=100, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 5/5; 54/96] START C=1, max_iter=100, penalty=l2, tol=0.0005.................
# [CV 5/5; 54/96] END C=1, max_iter=100, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# ...
# [CV 2/5; 79/96] START C=1.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 2/5; 79/96] END C=1.5, max_iter=250, penalty=l1, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 79/96] START C=1.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 3/5; 79/96] END C=1.5, max_iter=250, penalty=l1, tol=0.001;, score=0.983 total time=   0.0s
# [CV 4/5; 79/96] START C=1.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 4/5; 79/96] END C=1.5, max_iter=250, penalty=l1, tol=0.001;, score=0.978 total time=   0.0s
# [CV 5/5; 79/96] START C=1.5, max_iter=250, penalty=l1, tol=0.001................
# [CV 5/5; 79/96] END C=1.5, max_iter=250, penalty=l1, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 80/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 1/5; 80/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 2/5; 80/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 2/5; 80/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.994 total time=   0.1s
# [CV 3/5; 80/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 3/5; 80/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.983 total time=   0.1s
# [CV 4/5; 80/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 4/5; 80/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.978 total time=   0.0s
# [CV 5/5; 80/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0001...............
# [CV 5/5; 80/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 81/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 1/5; 81/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 2/5; 81/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 2/5; 81/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 81/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 3/5; 81/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.983 total time=   0.0s
# [CV 4/5; 81/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 4/5; 81/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.978 total time=   0.0s
# [CV 5/5; 81/96] START C=1.5, max_iter=250, penalty=l1, tol=0.0005...............
# [CV 5/5; 81/96] END C=1.5, max_iter=250, penalty=l1, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 1/5; 82/96] START C=1.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 1/5; 82/96] END C=1.5, max_iter=250, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 2/5; 82/96] START C=1.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 2/5; 82/96] END C=1.5, max_iter=250, penalty=l2, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 82/96] START C=1.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 3/5; 82/96] END C=1.5, max_iter=250, penalty=l2, tol=0.001;, score=0.961 total time=   0.0s
# [CV 4/5; 82/96] START C=1.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 4/5; 82/96] END C=1.5, max_iter=250, penalty=l2, tol=0.001;, score=0.983 total time=   0.0s
# [CV 5/5; 82/96] START C=1.5, max_iter=250, penalty=l2, tol=0.001................
# [CV 5/5; 82/96] END C=1.5, max_iter=250, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 83/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 1/5; 83/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 2/5; 83/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 2/5; 83/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 3/5; 83/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 3/5; 83/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 4/5; 83/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 4/5; 83/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.983 total time=   0.0s
# [CV 5/5; 83/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0001...............
# [CV 5/5; 83/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 84/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 1/5; 84/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 2/5; 84/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 2/5; 84/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 84/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 3/5; 84/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 4/5; 84/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 4/5; 84/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.983 total time=   0.0s
# [CV 5/5; 84/96] START C=1.5, max_iter=250, penalty=l2, tol=0.0005...............
# [CV 5/5; 84/96] END C=1.5, max_iter=250, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 1/5; 85/96] START C=1.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 1/5; 85/96] END C=1.5, max_iter=500, penalty=l1, tol=0.001;, score=0.994 total time=   0.0s
# [CV 2/5; 85/96] START C=1.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 2/5; 85/96] END C=1.5, max_iter=500, penalty=l1, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 85/96] START C=1.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 3/5; 85/96] END C=1.5, max_iter=500, penalty=l1, tol=0.001;, score=0.983 total time=   0.0s
# [CV 4/5; 85/96] START C=1.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 4/5; 85/96] END C=1.5, max_iter=500, penalty=l1, tol=0.001;, score=0.978 total time=   0.0s
# [CV 5/5; 85/96] START C=1.5, max_iter=500, penalty=l1, tol=0.001................
# [CV 5/5; 85/96] END C=1.5, max_iter=500, penalty=l1, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 86/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 1/5; 86/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 2/5; 86/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 2/5; 86/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.994 total time=   0.1s
# [CV 3/5; 86/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 3/5; 86/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.983 total time=   0.1s
# [CV 4/5; 86/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 4/5; 86/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.978 total time=   0.0s
# [CV 5/5; 86/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0001...............
# [CV 5/5; 86/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 87/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 1/5; 87/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 2/5; 87/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 2/5; 87/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 87/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 3/5; 87/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.983 total time=   0.0s
# [CV 4/5; 87/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 4/5; 87/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.978 total time=   0.0s
# [CV 5/5; 87/96] START C=1.5, max_iter=500, penalty=l1, tol=0.0005...............
# [CV 5/5; 87/96] END C=1.5, max_iter=500, penalty=l1, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 1/5; 88/96] START C=1.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 1/5; 88/96] END C=1.5, max_iter=500, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 2/5; 88/96] START C=1.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 2/5; 88/96] END C=1.5, max_iter=500, penalty=l2, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 88/96] START C=1.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 3/5; 88/96] END C=1.5, max_iter=500, penalty=l2, tol=0.001;, score=0.961 total time=   0.0s
# [CV 4/5; 88/96] START C=1.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 4/5; 88/96] END C=1.5, max_iter=500, penalty=l2, tol=0.001;, score=0.983 total time=   0.0s
# [CV 5/5; 88/96] START C=1.5, max_iter=500, penalty=l2, tol=0.001................
# [CV 5/5; 88/96] END C=1.5, max_iter=500, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 89/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 1/5; 89/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 2/5; 89/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 2/5; 89/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 3/5; 89/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 3/5; 89/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 4/5; 89/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 4/5; 89/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.983 total time=   0.0s
# [CV 5/5; 89/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0001...............
# [CV 5/5; 89/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 90/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 1/5; 90/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 2/5; 90/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 2/5; 90/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 90/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 3/5; 90/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 4/5; 90/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 4/5; 90/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.983 total time=   0.0s
# [CV 5/5; 90/96] START C=1.5, max_iter=500, penalty=l2, tol=0.0005...............
# [CV 5/5; 90/96] END C=1.5, max_iter=500, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 1/5; 91/96] START C=1.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 1/5; 91/96] END C=1.5, max_iter=750, penalty=l1, tol=0.001;, score=0.994 total time=   0.0s
# [CV 2/5; 91/96] START C=1.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 2/5; 91/96] END C=1.5, max_iter=750, penalty=l1, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 91/96] START C=1.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 3/5; 91/96] END C=1.5, max_iter=750, penalty=l1, tol=0.001;, score=0.983 total time=   0.0s
# [CV 4/5; 91/96] START C=1.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 4/5; 91/96] END C=1.5, max_iter=750, penalty=l1, tol=0.001;, score=0.978 total time=   0.0s
# [CV 5/5; 91/96] START C=1.5, max_iter=750, penalty=l1, tol=0.001................
# [CV 5/5; 91/96] END C=1.5, max_iter=750, penalty=l1, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 92/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 1/5; 92/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 2/5; 92/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 2/5; 92/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 3/5; 92/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 3/5; 92/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.983 total time=   0.1s
# [CV 4/5; 92/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 4/5; 92/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.978 total time=   0.0s
# [CV 5/5; 92/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0001...............
# [CV 5/5; 92/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 93/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 1/5; 93/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 2/5; 93/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 2/5; 93/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 93/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 3/5; 93/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.983 total time=   0.0s
# [CV 4/5; 93/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 4/5; 93/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.978 total time=   0.0s
# [CV 5/5; 93/96] START C=1.5, max_iter=750, penalty=l1, tol=0.0005...............
# [CV 5/5; 93/96] END C=1.5, max_iter=750, penalty=l1, tol=0.0005;, score=0.966 total time=   0.0s
# [CV 1/5; 94/96] START C=1.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 1/5; 94/96] END C=1.5, max_iter=750, penalty=l2, tol=0.001;, score=0.972 total time=   0.0s
# [CV 2/5; 94/96] START C=1.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 2/5; 94/96] END C=1.5, max_iter=750, penalty=l2, tol=0.001;, score=0.994 total time=   0.0s
# [CV 3/5; 94/96] START C=1.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 3/5; 94/96] END C=1.5, max_iter=750, penalty=l2, tol=0.001;, score=0.961 total time=   0.0s
# [CV 4/5; 94/96] START C=1.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 4/5; 94/96] END C=1.5, max_iter=750, penalty=l2, tol=0.001;, score=0.983 total time=   0.0s
# [CV 5/5; 94/96] START C=1.5, max_iter=750, penalty=l2, tol=0.001................
# [CV 5/5; 94/96] END C=1.5, max_iter=750, penalty=l2, tol=0.001;, score=0.966 total time=   0.0s
# [CV 1/5; 95/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 1/5; 95/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.972 total time=   0.0s
# [CV 2/5; 95/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 2/5; 95/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.994 total time=   0.0s
# [CV 3/5; 95/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 3/5; 95/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.961 total time=   0.0s
# [CV 4/5; 95/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 4/5; 95/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.983 total time=   0.0s
# [CV 5/5; 95/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0001...............
# [CV 5/5; 95/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0001;, score=0.966 total time=   0.0s
# [CV 1/5; 96/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 1/5; 96/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.972 total time=   0.0s
# [CV 2/5; 96/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 2/5; 96/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.994 total time=   0.0s
# [CV 3/5; 96/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 3/5; 96/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.961 total time=   0.0s
# [CV 4/5; 96/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 4/5; 96/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.983 total time=   0.0s
# [CV 5/5; 96/96] START C=1.5, max_iter=750, penalty=l2, tol=0.0005...............
# [CV 5/5; 96/96] END C=1.5, max_iter=750, penalty=l2, tol=0.0005;, score=0.966 total time=   0.0s
# Best score was 0.9832025610445043 and has parameters {'C': 1.5, 'max_iter': 100, 'penalty': 'l1', 'tol': 0.001}.

# %% [markdown]
# ## 12. Train a Single Model to Explore Fit

# %%
mdl_params = rsgislib.tools.utils.read_json_to_dict(mdl_params_file)


skl_mdl = LogisticRegression(
    solver="liblinear", fit_intercept=True, intercept_scaling=1, **mdl_params
)
train_acc, test_acc, roc_auc = species_distribution.fit_sklearn_mdl(
    est_cls_obj=skl_mdl,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    test_vec_file=pres_abs_std_test_vec_file,
    test_vec_lyr=pres_abs_std_test_vec_lyr,
    analysis_vars=analysis_vars,
    cls_col="clsid",
    roc_curve_plot=os.path.join(out_dir, "lr_testing_roc_curve.png"),
)

print(f"Train: {train_acc}")
print(f"Test: {test_acc}")
print(f"Test AUC: {roc_auc}")
# Out:
# Classifier Train Score = 98.66%
# Classifier Test Score = 97.32%
# Train: 0.9865771812080537
# Test: 0.9732142857142857
# Test AUC: 0.9908333333333332

# %% [markdown]
# ## 13. Jackknife Environmental Variable Importance

# %%
species_distribution.sklearn_jackknife_var_importance(
    est_cls_obj=skl_mdl,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    test_vec_file=pres_abs_std_test_vec_file,
    test_vec_lyr=pres_abs_std_test_vec_lyr,
    analysis_vars=analysis_vars,
    out_var_importance_file=os.path.join(out_dir, "jackknife_var_importance.csv"),
    out_importance_auc_plot=os.path.join(
        out_dir, "jackknife_var_importance_auc_plot.png"
    ),
    out_importance_test_plot=os.path.join(
        out_dir, "jackknife_var_importance_test_plot.png"
    ),
    cls_col="clsid",
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:01<00:00, 27.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:00<00:00, 452.58it/s]

# %% [markdown]
# ## 14. Environmental Variable Response Curves

# %%
species_distribution.sklearn_mdl_variable_response_curves(
    est_cls_obj = skl_mdl,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    analysis_vars=analysis_vars,
    output_file = os.path.join(out_dir, "var_response_curve_data.csv"),
    response_plots_dir = os.path.join(out_dir, "var_response_curves"),
    n_samples = 1000,
    cls_col = "clsid", 
    normalised_data = True,
    env_vars = env_vars,  
)
# Out:
# winter temperature Range:	(-2.1545550931844093 - 3.503034218061206): Mean = -0.8310569485620031
# quarry dist Range:	(-2.2615379714860087 - 2.0642672961269173): Mean = -1.0621712479658505
# lichenbryophyte heath dist Range:	(-2.579766855427128 - 2.6837202170492): Mean = -0.42247505126390295
# fen dist Range:	(-1.8493518311744603 - 2.7508573280627884): Mean = 0.3147709088859245
# mosaic dist Range:	(-0.6583547264842179 - 10.759837298516647): Mean = -0.35502844426758906
# blanket bog dist Range:	(-1.4889240492985765 - 2.1584836396874367): Mean = 0.5701297917310088
# wet heath dist Range:	(-1.484145155229312 - 3.598260687579188): Mean = 1.2836830410371622
# planted coniferous woodland dist Range:	(-1.419231779919152 - 3.0496173143411096): Mean = 1.4087476331396365
# natural rock exposure dist Range:	(-2.6790593907429057 - 2.700198849247526): Mean = -0.6229402673088253
# planted broadleaved woodland dist Range:	(-3.4205051571048157 - 3.170850124917415): Mean = 0.48298747934226693
# acidneutral scree dist Range:	(-1.671940431336383 - 3.3460043337944154): Mean = -0.7032353226314789
# improved grassland dist Range:	(-1.9654747954304677 - 2.689256718835557): Mean = 0.6211426778729259
# flush and spring dist Range:	(-2.018532032818866 - 2.0853609267816315): Mean = -1.3213051011221213
# ephemeralshort perennial dist Range:	(-3.9195139370482486 - 2.1594992988296897): Mean = -0.938588472614032
# unimproved calcareous grassland dist Range:	(-1.4771602376406239 - 2.2838530081190913): Mean = -0.9571466069175294
# spoil dist Range:	(-2.1734183563659215 - 2.074207383244751): Mean = -0.1040424276214667
# upland species rich ledges dist Range:	(-1.3764039014767897 - 3.720279480485312): Mean = -0.8827357588311417
# basin mire dist Range:	(-1.5933240120146543 - 4.218788393082092): Mean = 1.0570395354872535
# bare ground dist Range:	(-3.045916131236565 - 2.09159140832623): Mean = -1.1269527291562018
# semi natural broadleaved woodland dist Range:	(-1.8985564489765447 - 3.4521800820082915): Mean = 0.6478809448230035
# marshy grassland juncus dominated dist Range:	(-1.9795548234942046 - 2.374087291358342): Mean = -0.8884598343781127
# swamp dist Range:	(-2.3987890586779512 - 3.090289496930805): Mean = 0.4474050147775065
# basic dry heathcalcareous grassland mosaic dist Range:	(-1.4373750841148272 - 3.6289246671864808): Mean = 1.3903310982061166
# semi improved neutral grassland dist Range:	(-2.487166297225775 - 3.345226204836222): Mean = 0.4706297586986871
# semi improved acid grassland dist Range:	(-1.6301782002063239 - 3.378693780265467): Mean = 0.28966039755767575
# track not comprehensively digitised dist Range:	(-2.308792959665615 - 2.2221284912062655): Mean = -0.6033330202231648
# scree dist Range:	(-1.2000455090269007 - 2.4087003693686437): Mean = -0.6770503441319866
# wet heathacid grassland mosaic dist Range:	(-1.581430664873846 - 4.229827990755174): Mean = 0.21616417531685247
# dry modified bog dist Range:	(-1.848829917447249 - 3.5698040672184854): Mean = 0.49291037399572013
# non ruderal herb and fern dist Range:	(-1.9628856731960023 - 2.236167106294719): Mean = -1.2881261532543704
# marshy grassland molinia dominated dist Range:	(-1.483816035102422 - 3.08884100360642): Mean = 0.538165364685261
# marshy grassland dist Range:	(-1.8154230701094984 - 3.0350569174654805): Mean = 0.4355566524090313
# other rock exposure dist Range:	(-1.8071567590290847 - 3.781363637011768): Mean = -0.11154997670351414
# dry acid heath dist Range:	(-1.2349511033620184 - 3.0691764783189592): Mean = -0.07503052030758324
# buildings dist Range:	(-1.8629319399256572 - 3.3464409611668144): Mean = 0.2490318961114582
# dense scrub dist Range:	(-1.829109123485289 - 3.328369850703857): Mean = -0.2347053931128497
# standing water dist Range:	(-1.6011468178123982 - 4.122432642693967): Mean = -0.6926855058422886
# acidneutral rock dist Range:	(-2.2141058730068703 - 3.297500312776256): Mean = -0.2538905740634074
# unimproved acid grassland dist Range:	(-0.7772762424171682 - 4.681179142536977): Mean = -0.5268017410802498
# running water dist Range:	(-1.5163669373789839 - 3.515781461548624): Mean = 0.4416716660482578
# gardens dist Range:	(-2.9837119118012168 - 2.062543879762382): Mean = -1.1363341401578348
# acidneutral flush dist Range:	(-1.3578152261924517 - 5.032575307482018): Mean = 1.4116444313451775
# brophyte dominated spring dist Range:	(-1.9047235914554737 - 2.7167590169333464): Mean = -0.45182962522956055
# bare peat dist Range:	(-4.157020467857671 - 3.0229851068673432): Mean = 0.7058901972050671
# amenity grassland dist Range:	(-2.351489366953727 - 2.12812495088191): Mean = -1.2132239355205867
# bracken dist Range:	(-1.2296726221397212 - 3.7606051525250788): Mean = 1.4885516924578512
# wet modified bog dist Range:	(-1.0736293087646571 - 3.85175539400717): Mean = 1.110215936658998
# Calculating Response Curve for 'winter temperature'
# Calculating Response Curve for 'quarry dist'
# Calculating Response Curve for 'lichenbryophyte heath dist'
# Calculating Response Curve for 'fen dist'
# Calculating Response Curve for 'mosaic dist'
# Calculating Response Curve for 'blanket bog dist'
# Calculating Response Curve for 'wet heath dist'
# Calculating Response Curve for 'planted coniferous woodland dist'
# Calculating Response Curve for 'natural rock exposure dist'
# Calculating Response Curve for 'planted broadleaved woodland dist'
# Calculating Response Curve for 'acidneutral scree dist'
# Calculating Response Curve for 'improved grassland dist'
# Calculating Response Curve for 'flush and spring dist'
# Calculating Response Curve for 'ephemeralshort perennial dist'
# Calculating Response Curve for 'unimproved calcareous grassland dist'
# Calculating Response Curve for 'spoil dist'
# Calculating Response Curve for 'upland species rich ledges dist'
# Calculating Response Curve for 'basin mire dist'
# Calculating Response Curve for 'bare ground dist'
# Calculating Response Curve for 'semi natural broadleaved woodland dist'
# Calculating Response Curve for 'marshy grassland juncus dominated dist'
# Calculating Response Curve for 'swamp dist'
# Calculating Response Curve for 'basic dry heathcalcareous grassland mosaic dist'
# Calculating Response Curve for 'semi improved neutral grassland dist'
# Calculating Response Curve for 'semi improved acid grassland dist'
# /Users/pfb/Temp/rsgislib_osian_sdm/andy_sdm_tutorial/rsgislib_tutorial/13_species_distribution_modelling/species_distribution.py:1395: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# Calculating Response Curve for 'track not comprehensively digitised dist'
# Calculating Response Curve for 'scree dist'
# Calculating Response Curve for 'wet heathacid grassland mosaic dist'
# Calculating Response Curve for 'dry modified bog dist'
# Calculating Response Curve for 'non ruderal herb and fern dist'
# Calculating Response Curve for 'marshy grassland molinia dominated dist'
# Calculating Response Curve for 'marshy grassland dist'
# Calculating Response Curve for 'other rock exposure dist'
# Calculating Response Curve for 'dry acid heath dist'
# Calculating Response Curve for 'buildings dist'
# Calculating Response Curve for 'dense scrub dist'
# Calculating Response Curve for 'standing water dist'
# Calculating Response Curve for 'acidneutral rock dist'
# Calculating Response Curve for 'unimproved acid grassland dist'
# Calculating Response Curve for 'running water dist'
# Calculating Response Curve for 'gardens dist'
# Calculating Response Curve for 'acidneutral flush dist'
# Calculating Response Curve for 'brophyte dominated spring dist'
# Calculating Response Curve for 'bare peat dist'
# Calculating Response Curve for 'amenity grassland dist'
# Calculating Response Curve for 'bracken dist'
# Calculating Response Curve for 'wet modified bog dist'

# %% [markdown]
# ## 15. SHAP Model Explainer

# %%
species_distribution.shap_sklearn_mdl_explainer(
    est_cls_obj=skl_mdl,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    analysis_vars=analysis_vars,
    shap_summary_plot=os.path.join(out_dir, "shap_summary_plot.png"),
    shap_heatmap_plot=os.path.join(out_dir, "shap_heatmap.png"),
    shap_scatter_plots_dir=os.path.join(out_dir, "shap_scatter_plots"),
    shap_depend_plots_dir=os.path.join(out_dir, "shap_dependence_plots"),
    subsample_n_smpls=None,
    use_tree_explainer = False,
    use_linear_explainer = True,
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# /Users/pfb/miniconda3/envs/osgeo-env-v9/lib/python3.12/site-packages/shap/explainers/_linear.py:95: FutureWarning: The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, maskers.Partition or maskers.Impute).
#   warnings.warn(wmsg, FutureWarning)
# Estimating transforms:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 species_distribution.shap_sklearn_mdl_explainer(
#       2     est_cls_obj=skl_mdl,
#       3     train_vec_file=pres_abs_std_train_vec_file,
#       4     train_vec_lyr=pres_abs_std_train_vec_lyr,
#       5     analysis_vars=analysis_vars,
#       6     shap_summary_plot=os.path.join(out_dir, "shap_summary_plot.png"),
#       7     shap_heatmap_plot=os.path.join(out_dir, "shap_heatmap.png"),
#       8     shap_scatter_plots_dir=os.path.join(out_dir, "shap_scatter_plots"),
#       9     shap_depend_plots_dir=os.path.join(out_dir, "shap_dependence_plots"),
#      10     subsample_n_smpls=None,
#      11     use_tree_explainer = False,
#      12     use_linear_explainer = True,
#      13 )
#
# File ~/Temp/rsgislib_osian_sdm/andy_sdm_tutorial/rsgislib_tutorial/13_species_distribution_modelling/species_distribution.py:1202, in shap_sklearn_mdl_explainer(est_cls_obj, train_vec_file, train_vec_lyr, analysis_vars, shap_summary_plot, shap_heatmap_plot, shap_scatter_plots_dir, shap_depend_plots_dir, subsample_n_smpls, use_tree_explainer, use_linear_explainer)
#    1197 for i, name in enumerate(analysis_vars):
#    1198     out_plot_file = os.path.join(
#    1199         shap_depend_plots_dir, f"shap_depends_{name}.png"
#    1200     )
# -> 1202     fig, ax = shap.partial_dependence_plot(
#    1203         name,
#    1204         est_cls_obj.predict_proba,
#    1205         train_x_smpl,
#    1206         model_expected_value=True,
#    1207         feature_expected_value=True,
#    1208         show=show_plots,
#    1209         ice=False,
#    1210         shap_values=shap_values[sample_ind : sample_ind + 1, :],
#    1211     )
#    1213     plt.savefig(out_plot_file)
#    1214     plt.clf()
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ## 16. Model Sensitivity Analysis

# %%
species_distribution.salib_sklearn_mdl_sensitity(
    est_cls_obj = skl_mdl,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    analysis_vars=analysis_vars,
    n_samples = 1000,
    sobol_plot_file = os.path.join(out_dir, "sobol_sa_plot.png"),
    sobol_overall_file = os.path.join(out_dir, "sobol_sa_overall.csv"),
    sobol_first_file = os.path.join(out_dir, "sobol_sa_first_order.csv"),
    sobol_second_file = os.path.join(out_dir, "sobol_sa_second_order.csv"),
)
# Out:
# winter temperature Range:	(-2.1545550931844093 - 3.503034218061206)
# quarry dist Range:	(-2.2615379714860087 - 2.0642672961269173)
# lichenbryophyte heath dist Range:	(-2.579766855427128 - 2.6837202170492)
# fen dist Range:	(-1.8493518311744603 - 2.7508573280627884)
# mosaic dist Range:	(-0.6583547264842179 - 10.759837298516647)
# blanket bog dist Range:	(-1.4889240492985765 - 2.1584836396874367)
# wet heath dist Range:	(-1.484145155229312 - 3.598260687579188)
# planted coniferous woodland dist Range:	(-1.419231779919152 - 3.0496173143411096)
# natural rock exposure dist Range:	(-2.6790593907429057 - 2.700198849247526)
# planted broadleaved woodland dist Range:	(-3.4205051571048157 - 3.170850124917415)
# acidneutral scree dist Range:	(-1.671940431336383 - 3.3460043337944154)
# improved grassland dist Range:	(-1.9654747954304677 - 2.689256718835557)
# flush and spring dist Range:	(-2.018532032818866 - 2.0853609267816315)
# ephemeralshort perennial dist Range:	(-3.9195139370482486 - 2.1594992988296897)
# unimproved calcareous grassland dist Range:	(-1.4771602376406239 - 2.2838530081190913)
# spoil dist Range:	(-2.1734183563659215 - 2.074207383244751)
# upland species rich ledges dist Range:	(-1.3764039014767897 - 3.720279480485312)
# basin mire dist Range:	(-1.5933240120146543 - 4.218788393082092)
# bare ground dist Range:	(-3.045916131236565 - 2.09159140832623)
# semi natural broadleaved woodland dist Range:	(-1.8985564489765447 - 3.4521800820082915)
# marshy grassland juncus dominated dist Range:	(-1.9795548234942046 - 2.374087291358342)
# swamp dist Range:	(-2.3987890586779512 - 3.090289496930805)
# basic dry heathcalcareous grassland mosaic dist Range:	(-1.4373750841148272 - 3.6289246671864808)
# semi improved neutral grassland dist Range:	(-2.487166297225775 - 3.345226204836222)
# semi improved acid grassland dist Range:	(-1.6301782002063239 - 3.378693780265467)
# track not comprehensively digitised dist Range:	(-2.308792959665615 - 2.2221284912062655)
# scree dist Range:	(-1.2000455090269007 - 2.4087003693686437)
# wet heathacid grassland mosaic dist Range:	(-1.581430664873846 - 4.229827990755174)
# dry modified bog dist Range:	(-1.848829917447249 - 3.5698040672184854)
# non ruderal herb and fern dist Range:	(-1.9628856731960023 - 2.236167106294719)
# marshy grassland molinia dominated dist Range:	(-1.483816035102422 - 3.08884100360642)
# marshy grassland dist Range:	(-1.8154230701094984 - 3.0350569174654805)
# other rock exposure dist Range:	(-1.8071567590290847 - 3.781363637011768)
# dry acid heath dist Range:	(-1.2349511033620184 - 3.0691764783189592)
# buildings dist Range:	(-1.8629319399256572 - 3.3464409611668144)
# dense scrub dist Range:	(-1.829109123485289 - 3.328369850703857)
# standing water dist Range:	(-1.6011468178123982 - 4.122432642693967)
# acidneutral rock dist Range:	(-2.2141058730068703 - 3.297500312776256)
# unimproved acid grassland dist Range:	(-0.7772762424171682 - 4.681179142536977)
# running water dist Range:	(-1.5163669373789839 - 3.515781461548624)
# gardens dist Range:	(-2.9837119118012168 - 2.062543879762382)
# acidneutral flush dist Range:	(-1.3578152261924517 - 5.032575307482018)
# brophyte dominated spring dist Range:	(-1.9047235914554737 - 2.7167590169333464)
# bare peat dist Range:	(-4.157020467857671 - 3.0229851068673432)
# amenity grassland dist Range:	(-2.351489366953727 - 2.12812495088191)
# bracken dist Range:	(-1.2296726221397212 - 3.7606051525250788)
# wet modified bog dist Range:	(-1.0736293087646571 - 3.85175539400717)
# /Users/pfb/miniconda3/envs/osgeo-env-v9/lib/python3.12/site-packages/scipy/stats/_qmc.py:958: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# /Users/pfb/miniconda3/envs/osgeo-env-v9/lib/python3.12/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %% [markdown]
# ## 17. Create Ensemble of Models
#
# Using a k-fold analysis a set of models are created with different subsets of the training data

# %%
skl_mdl = LogisticRegression(solver='liblinear', fit_intercept=True, intercept_scaling=1, **mdl_params)

skl_mdls = species_distribution.fit_kfold_sklearn_mdls(
    est_cls_obj=skl_mdl,
    train_vec_file=pres_abs_std_train_vec_file,
    train_vec_lyr=pres_abs_std_train_vec_lyr,
    test_vec_file=pres_abs_std_test_vec_file,
    test_vec_lyr=pres_abs_std_test_vec_lyr,
    analysis_vars=analysis_vars,
    n_kfolds=25,
    cls_col="clsid",
    rnd_seed=None,
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 84.06it/s]
# ROC: 0.9447916666666667 - 0.9733333333333334 - 0.9908333333333333
# Train: 0.9701492537313433 - 0.9832089552238806 - 0.9925373134328358
# Test: 0.9598214285714286 - 0.96875 - 0.9866071428571429

# %% [markdown]
# ## 18. Create an SDM Output Summarising Hard Classification
#
# This first analysis runs the ensemble of classifiers producing a set of hard (binary) classifications which are then summarised as a proportion of classifications which are mapped as presence.

# %%
out_cls_img = os.path.join(out_dir, "Snowdon_Beetle_sdm_cls_prob.tif")

species_distribution.pred_ensemble_sklearn_mdls_cls(
    est_cls_objs=skl_mdls,
    in_msk_img=study_site_msk_img,
    img_msk_val=1,
    env_vars=env_vars,
    analysis_vars=analysis_vars,
    output_img=out_cls_img,
    gdalformat="GTIFF",
    tmp_dir=tmp_dir,
    normalise_data=True,
    calc_img_stats=True,
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_0.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_1.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_2.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_3.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_4.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_5.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_6.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_7.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_8.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_9.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_10.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_11.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_12.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_13.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_14.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_15.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_16.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_17.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_18.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_19.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_20.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_21.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_22.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_23.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_cls_prob_24.tif
# New image width = 757 height = 596 bands = 1
#
# Image: Study_Area.tif
# 	 Variable 'msk' is band 1
# Image: tmp_dir/Snowdon_Beetle_sdm_cls_prob_sum.tif
# 	 Variable 'sum_img' is band 1
# New image width = 757 height = 596 bands = 1
#
#
#
# Calculating Image Pyramids.

# %%
# Create a plot using the matplotlib library
fig, ax = plt.subplots(figsize=(5, 5))

rsgislib.tools.mapping.create_raster_cmap_img_map(
    ax,
    input_img=out_cls_img,
    img_band=1,
    title_str="Snowdon Beetle SDM",
)
ax.tick_params(axis="x", labelrotation=45)
# Out:
# Image Data Size: 757 x 596

# %% [markdown]
# ## 19. Create an SDM Output Summarising Model Probability Outputs
#
# This second analysis runs the ensemble of classifiers producing a probability output which are then summarised as the median probability from all the models

# %%
out_prob_img = os.path.join(out_dir, "Snowdon_Beetle_sdm_med_prob.tif")

species_distribution.pred_ensemble_sklearn_mdls_prob(
    est_cls_objs=skl_mdls,
    in_msk_img=study_site_msk_img,
    img_msk_val=1,
    env_vars=env_vars,
    analysis_vars=analysis_vars,
    output_img=out_prob_img,
    gdalformat="GTIFF",
    tmp_dir=tmp_dir,
    normalise_data=True,
    calc_img_stats=True,
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_0.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_1.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_2.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_3.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_4.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_5.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_6.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_7.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_8.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_9.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_10.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_11.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_12.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_13.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_14.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_15.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_16.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_17.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_18.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_19.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_20.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_21.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_22.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_23.tif
# Opening tmp_dir/Snowdon_Beetle_sdm_med_prob_24.tif
# New image width = 757 height = 596 bands = 1
#
#
#
# Calculating Image Pyramids.

# %%
# Create a plot using the matplotlib library
fig, ax = plt.subplots(figsize=(5, 5))

rsgislib.tools.mapping.create_raster_cmap_img_map(
    ax,
    input_img=out_prob_img,
    img_band=1,
    title_str="Snowdon Beetle SDM",
)
ax.tick_params(axis="x", labelrotation=45)
# Out:
# Image Data Size: 757 x 596
